# %%
#Import all needed Packages

import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

# %%
#Set path to .csv file
IMDB_df = pd.read_csv('IMDB_Horror_Movies.csv')
IMDB_df.head()
# Out:
#                                  Title                     Genres  \
# 0                           Gut (2012)    Drama| Horror| Thriller
# 1      The Haunting of Mia Moss (2017)                     Horror
# 2                  Sleepwalking (2017)                     Horror
# 3  Treasure Chest of Horrors II (2013)   Comedy| Horror| Thriller
# 4                       Infidus (2015)       Crime| Drama| Horror
#
#   Release Date Release Country Movie Rating  Review Rating Movie Run Time  \
# 0    26-Oct-12             USA          NaN            3.9         91 min
# 1    13-Jan-17             USA          NaN            NaN            NaN
# 2    21-Oct-17          Canada          NaN            NaN            NaN
# 3    23-Apr-13             USA    NOT RATED            3.7         82 min
# 4    10-Apr-15             USA          NaN            5.8         80 min
#
#                                                 Plot  \
# 0  Directed by Elias. With Jason Vail, Nicholas W...
# ...

# %%
IMDB_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3328 entries, 0 to 3327
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              3328 non-null   object
#  1   Genres             3327 non-null   object
#  2   Release Date       3328 non-null   object
#  3   Release Country    3328 non-null   object
#  4   Movie Rating       1451 non-null   object
#  5   Review Rating      3076 non-null   float64
#  6   Movie Run Time     2784 non-null   object
#  7   Plot               3327 non-null   object
#  8   Cast               3314 non-null   object
#  9   Language           3257 non-null   object
#  10  Filming Locations  2096 non-null   object
#  11  Budget             1234 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 312.1+ KB

# %%
# Clean .csv file

    # Split out release month and release year
    IMDB_df['Release Year'] = pd.DatetimeIndex(IMDB_df['Release Date']).year
    IMDB_df['Release Month'] = pd.DatetimeIndex(IMDB_df['Release Date']).month_name()
    IMDB_df.head()
# Out:
#                                  Title                     Genres  \
# 0                           Gut (2012)    Drama| Horror| Thriller
# 1      The Haunting of Mia Moss (2017)                     Horror
# 2                  Sleepwalking (2017)                     Horror
# 3  Treasure Chest of Horrors II (2013)   Comedy| Horror| Thriller
# 4                       Infidus (2015)       Crime| Drama| Horror
#
#   Release Date Release Country Movie Rating  Review Rating Movie Run Time  \
# 0    26-Oct-12             USA          NaN            3.9         91 min
# 1    13-Jan-17             USA          NaN            NaN            NaN
# 2    21-Oct-17          Canada          NaN            NaN            NaN
# 3    23-Apr-13             USA    NOT RATED            3.7         82 min
# 4    10-Apr-15             USA          NaN            5.8         80 min
#
#                                                 Plot  \
# 0  Directed by Elias. With Jason Vail, Nicholas W...
# ...

# %%
    # 
IMDB_df.head()
# Out:
#                                  Title                     Genres  \
# 0                           Gut (2012)    Drama| Horror| Thriller
# 1      The Haunting of Mia Moss (2017)                     Horror
# 2                  Sleepwalking (2017)                     Horror
# 3  Treasure Chest of Horrors II (2013)   Comedy| Horror| Thriller
# 4                       Infidus (2015)       Crime| Drama| Horror
#
#   Release Date Release Country Movie Rating  Review Rating Movie Run Time  \
# 0    26-Oct-12             USA          NaN            3.9         91 min
# 1    13-Jan-17             USA          NaN            NaN            NaN
# 2    21-Oct-17          Canada          NaN            NaN            NaN
# 3    23-Apr-13             USA    NOT RATED            3.7         82 min
# 4    10-Apr-15             USA          NaN            5.8         80 min
#
#                                                 Plot  \
# 0  Directed by Elias. With Jason Vail, Nicholas W...
# ...

# %%
IMDB_Clean2_df[['Day', 'Month', 'Year']] =  IMDB_Date_df.str.split("-", expand = True)
print(IMDB_df.count())
IMDB_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 IMDB_df[['Day', 'Month', 'Year']] =  IMDB_df.str.split("-", expand = True)
#       2 IMDB_df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
IMDB_df.count()
# Out:
# Title                1960
# Genres               1960
# Release Date         1960
# Release Country      1960
# Review Rating        1960
# Filming Locations    1960
# Day                  1960
# Month                1865
# Year                 1865
# Release Year         1960
# dtype: int64

# %%
IMDB_df.head(30)
# Out:
#                                        Title
# 0                                 Gut (2012)  \
# 3        Treasure Chest of Horrors II (2013)
# 7                    Parasyte: Part 2 (2015)
# 8               Stranger in the House (2015)
# 11                Rise of the Animals (2011)
# 14                         Sexy Durga (2017)
# 15                 Circus of the Dead (2014)
# 16                Zombie Resurrection (2014)
# 17                            Falling (2016)
# 19                      Devil's Tower (2014)
# 20                          I Am ZoZo (2012)
# 21                        Before Dawn (2013)
# 22                         Apparition (2015)
# 24       Don't Look in the Basement 2 (2015)
# 25                  2: Voodoo Academy (2012)
# 28                         Septic Man (2013)
# 30  Her Cry: La Llorona Investigation (2013)
# 31                        The Canadoo (2016)
# 36                        Ular Tangga (2017)
# 38      Haunted House on Sorority Row (2014)
# ...

# %%
IMDB_df = IMDB_df.dropna()

IMDB_df.head(30)
# Out:
#                                        Title
# 0                                 Gut (2012)  \
# 3        Treasure Chest of Horrors II (2013)
# 7                    Parasyte: Part 2 (2015)
# 8               Stranger in the House (2015)
# 11                Rise of the Animals (2011)
# 14                         Sexy Durga (2017)
# 15                 Circus of the Dead (2014)
# 16                Zombie Resurrection (2014)
# 17                            Falling (2016)
# 19                      Devil's Tower (2014)
# 20                          I Am ZoZo (2012)
# 21                        Before Dawn (2013)
# 22                         Apparition (2015)
# 24       Don't Look in the Basement 2 (2015)
# 25                  2: Voodoo Academy (2012)
# 28                         Septic Man (2013)
# 30  Her Cry: La Llorona Investigation (2013)
# 31                        The Canadoo (2016)
# 36                        Ular Tangga (2017)
# 38      Haunted House on Sorority Row (2014)
# ...
