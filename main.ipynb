# %%
#Import all needed Packages

import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

# %%
#Set path to .csv file
IMDB_df = pd.read_csv('IMDB_Horror_Movies.csv')
IMDB_df.head()
# Out:
#                                  Title                     Genres  \
# 0                           Gut (2012)    Drama| Horror| Thriller
# 1      The Haunting of Mia Moss (2017)                     Horror
# 2                  Sleepwalking (2017)                     Horror
# 3  Treasure Chest of Horrors II (2013)   Comedy| Horror| Thriller
# 4                       Infidus (2015)       Crime| Drama| Horror
#
#   Release Date Release Country Movie Rating  Review Rating Movie Run Time  \
# 0    26-Oct-12             USA          NaN            3.9         91 min
# 1    13-Jan-17             USA          NaN            NaN            NaN
# 2    21-Oct-17          Canada          NaN            NaN            NaN
# 3    23-Apr-13             USA    NOT RATED            3.7         82 min
# 4    10-Apr-15             USA          NaN            5.8         80 min
#
#                                                 Plot  \
# 0  Directed by Elias. With Jason Vail, Nicholas W...
# ...

# %%
IMDB_df[['Genre 1','Genre 2', 'Genre 3', 'Genre 4', 'Genre 5', 'Genre 6', 'Genre 7', 'Genre 8']]=IMDB_df.Genres.str.split('|',expand=True)
IMDB_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 IMDB_df[['Genre 1','Genre 2', 'Genre 3', 'Genre 4', 'Genre 5', 'Genre 6', 'Genre 7', 'Genre 8']]=IMDB_df.Genres.str.split('|',expand=True)
#       2 IMDB_df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_frame(key, value)
#    3967 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
#    3970     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4010, in DataFrame._setitem_array(self, key, value)
#    4005 else:
#    4006     # Note: unlike self.iloc[:, indexer] = value, this will
#    4007     #  never try to overwrite values inplace
# ...

# %%
#Clean .csv file
IMDB_df['Release Year'] = pd.DatetimeIndex(IMDB_df['Release Date']).year
IMDB_df.head()
# Out:
#                                  Title                     Genres  \
# 0                           Gut (2012)    Drama| Horror| Thriller
# 1      The Haunting of Mia Moss (2017)                     Horror
# 2                  Sleepwalking (2017)                     Horror
# 3  Treasure Chest of Horrors II (2013)   Comedy| Horror| Thriller
# 4                       Infidus (2015)       Crime| Drama| Horror
#
#   Release Date Release Country Movie Rating  Review Rating Movie Run Time  \
# 0    26-Oct-12             USA          NaN            3.9         91 min
# 1    13-Jan-17             USA          NaN            NaN            NaN
# 2    21-Oct-17          Canada          NaN            NaN            NaN
# 3    23-Apr-13             USA    NOT RATED            3.7         82 min
# 4    10-Apr-15             USA          NaN            5.8         80 min
#
#                                                 Plot  \
# 0  Directed by Elias. With Jason Vail, Nicholas W...
# ...

# %%
#IMBD_df['Release Month'] = pd.DatetimeIndex(IMDB_df['Release Date']).month
#IMDB_df.head()
